# %% [markdown]
# # 모델 학습 및 테스트 용 노트북
#
# ### 현업에서 실제로 사용할 수 있도록 간략화
#
# ### 사용법
#
# #### 1) 경로 설정
# - 절대 경로 혹은 상대경로로 설정
#
# #### 2) 최초 학습이거나 새로운 데이터를 학습시키고자 할 경우
# - 1번 -> 2번 -> 3번 -> 4번 순으로 모두 구동
#
# #### 3) 저장된 모델을 사용하여 바로 검사하고자 할 경우
# - 1번 -> 2번 -> 4번 순으로 실행(3번 학습 과정은 제외)

# %% [markdown]
# ## 0. 경로 설정

# %%
# 최상위 폴더 경로
folder_path = 'C:\\Users\\박인창\\OneDrive - 한양대학교\\1 제조AI 공모전\\KAMP_모델코드'

# %%
# 데이터가 담긴 폴더 경로 및 데이터명
data_path = 'C:\\Users\\박인창\\OneDrive - 한양대학교\\1 제조AI 공모전\\FINAL_MODEL\data\\'
data_name = '경진대회용 사출성형기 데이터셋_labeled.csv'

# %%
# 저장된 모델의 경로
saved_model_path = 'C:\\Users\\박인창\\OneDrive - 한양대학교\\1 제조AI 공모전\\FINAL_MODEL\\saved_model\\'

# %% [markdown]
# ## 1. 외부 class 및 함수 로딩

# %%
# Class 정보를 불러오기 위해 필요
# 가장 상위 파일의 절대 경로 혹은 상대경로 이정
import sys
sys.path.append(folder_path)
print(sys.path)
# Out:
# ['C:\\Users\\박인창\\Desktop\\FINAL_MODEL', 'C:\\ProgramData\\anaconda3\\python38.zip', 'C:\\ProgramData\\anaconda3\\DLLs', 'C:\\ProgramData\\anaconda3\\lib', 'C:\\ProgramData\\anaconda3', '', 'C:\\ProgramData\\anaconda3\\lib\\site-packages', 'C:\\ProgramData\\anaconda3\\lib\\site-packages\\locket-0.2.1-py3.8.egg', 'C:\\ProgramData\\anaconda3\\lib\\site-packages\\win32', 'C:\\ProgramData\\anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\ProgramData\\anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\ProgramData\\anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\박인창\\.ipython', 'C:\\Users\\박인창\\OneDrive - 한양대학교\\1 제조AI 공모전\\FINAL_MODEL']

# %%
from utils.tools import *
from utils.model import *
from utils.Preprocessor import Preprocessor

# %% [markdown]
# ## 2. 데이터 로드 및 전처리

# %%
train_loader, val_loader, test_loader, scaler, labels, w_size, z_size, window_size, col_names, cn7_Y  = Preprocessor(data_path+data_name).preprocessing_4_train()
# Out:
# Preprocessor is Operating
# C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ## 3. Training
# - 처음 학습하거나 새로운 데이터를 학습시켜야할 경우 사용
# - 학습 후 saved_model에 모델 가중치 저장

# %%
device = get_default_device()
model = UsadModel(w_size, z_size)
model = to_device(model,device)

# %%
history = training(80,model,train_loader,val_loader)
# Out:
# Epoch [0], val_loss1: 0.0137, val_loss2: 0.0114
# Epoch [1], val_loss1: 0.0103, val_loss2: -0.0010
# Epoch [2], val_loss1: 0.0098, val_loss2: -0.0045
# Epoch [3], val_loss1: 0.0097, val_loss2: -0.0060
# Epoch [4], val_loss1: 0.0099, val_loss2: -0.0069
# Epoch [5], val_loss1: 0.0099, val_loss2: -0.0075
# Epoch [6], val_loss1: 0.0100, val_loss2: -0.0079
# Epoch [7], val_loss1: 0.0101, val_loss2: -0.0083
# Epoch [8], val_loss1: 0.0101, val_loss2: -0.0085
# Epoch [9], val_loss1: 0.0102, val_loss2: -0.0088
# Epoch [10], val_loss1: 0.0104, val_loss2: -0.0091
# Epoch [11], val_loss1: 0.0103, val_loss2: -0.0091
# Epoch [12], val_loss1: 0.0103, val_loss2: -0.0092
# Epoch [13], val_loss1: 0.0103, val_loss2: -0.0093
# Epoch [14], val_loss1: 0.0104, val_loss2: -0.0094
# Epoch [15], val_loss1: 0.0104, val_loss2: -0.0095
# Epoch [16], val_loss1: 0.0104, val_loss2: -0.0096
# Epoch [17], val_loss1: 0.0104, val_loss2: -0.0097
# Epoch [18], val_loss1: 0.0105, val_loss2: -0.0097
# Epoch [19], val_loss1: 0.0105, val_loss2: -0.0098
# Epoch [20], val_loss1: 0.0105, val_loss2: -0.0098
# Epoch [21], val_loss1: 0.0105, val_loss2: -0.0099
# Epoch [22], val_loss1: 0.0105, val_loss2: -0.0099
# Epoch [23], val_loss1: 0.0106, val_loss2: -0.0100
# Epoch [24], val_loss1: 0.0106, val_loss2: -0.0100
# Epoch [25], val_loss1: 0.0106, val_loss2: -0.0101
# Epoch [26], val_loss1: 0.0106, val_loss2: -0.0101
# Epoch [27], val_loss1: 0.0106, val_loss2: -0.0101
# Epoch [28], val_loss1: 0.0107, val_loss2: -0.0102
# Epoch [29], val_loss1: 0.0107, val_loss2: -0.0102
# Epoch [30], val_loss1: 0.0107, val_loss2: -0.0102
# Epoch [31], val_loss1: 0.0107, val_loss2: -0.0103
# Epoch [32], val_loss1: 0.0107, val_loss2: -0.0103
# Epoch [33], val_loss1: 0.0108, val_loss2: -0.0104
# Epoch [34], val_loss1: 0.0108, val_loss2: -0.0104
# Epoch [35], val_loss1: 0.0108, val_loss2: -0.0104
# Epoch [36], val_loss1: 0.0109, val_loss2: -0.0105
# Epoch [37], val_loss1: 0.0109, val_loss2: -0.0105
# Epoch [38], val_loss1: 0.0109, val_loss2: -0.0106
# Epoch [39], val_loss1: 0.0109, val_loss2: -0.0106
# Epoch [40], val_loss1: 0.0110, val_loss2: -0.0106
# Epoch [41], val_loss1: 0.0110, val_loss2: -0.0106
# Epoch [42], val_loss1: 0.0110, val_loss2: -0.0106
# Epoch [43], val_loss1: 0.0110, val_loss2: -0.0107
# Epoch [44], val_loss1: 0.0110, val_loss2: -0.0107
# Epoch [45], val_loss1: 0.0110, val_loss2: -0.0107
# Epoch [46], val_loss1: 0.0110, val_loss2: -0.0107
# Epoch [47], val_loss1: 0.0110, val_loss2: -0.0107
# Epoch [48], val_loss1: 0.0111, val_loss2: -0.0108
# Epoch [49], val_loss1: 0.0118, val_loss2: -0.0115
# Epoch [50], val_loss1: 0.0110, val_loss2: -0.0107
# Epoch [51], val_loss1: 0.0111, val_loss2: -0.0108
# Epoch [52], val_loss1: 0.0111, val_loss2: -0.0108
# Epoch [53], val_loss1: 0.0111, val_loss2: -0.0108
# Epoch [54], val_loss1: 0.0111, val_loss2: -0.0109
# Epoch [55], val_loss1: 0.0111, val_loss2: -0.0109
# Epoch [56], val_loss1: 0.0111, val_loss2: -0.0109
# Epoch [57], val_loss1: 0.0111, val_loss2: -0.0109
# Epoch [58], val_loss1: 0.0112, val_loss2: -0.0109
# Epoch [59], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [60], val_loss1: 0.0111, val_loss2: -0.0109
# Epoch [61], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [62], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [63], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [64], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [65], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [66], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [67], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [68], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [69], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [70], val_loss1: 0.0113, val_loss2: -0.0111
# Epoch [71], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [72], val_loss1: 0.0111, val_loss2: -0.0110
# Epoch [73], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [74], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [75], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [76], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [77], val_loss1: 0.0112, val_loss2: -0.0110
# Epoch [78], val_loss1: 0.0112, val_loss2: -0.0111
# Epoch [79], val_loss1: 0.0112, val_loss2: -0.0111

# %%
plot_history(history)

# %% [markdown]
# #### 모델 저장

# %%
torch.save({
            'encoder': model.encoder.state_dict(),
            'decoder1': model.decoder1.state_dict(),
            'decoder2': model.decoder2.state_dict()
            }, saved_model_path+"AI_model.pth")

# %% [markdown]
# ## 4. Testing

# %% [markdown]
# #### 모델 로딩

# %%
checkpoint = torch.load(saved_model_path+"AI_model.pth")

device = get_default_device()
model = UsadModel(w_size, z_size)
model = to_device(model,device)

model.encoder.load_state_dict(checkpoint['encoder'])
model.decoder1.load_state_dict(checkpoint['decoder1'])
model.decoder2.load_state_dict(checkpoint['decoder2'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### 검사 결과
#
# #### 해석 가이드
# - 1) time : 이상이 감지된 시간(데이터 순번)
# - 2) 이상 보고 : 이상이 감지된 각 변수가 정상 범주와 어느 정도 차이가 있는지를 표시

# %%
results,outputs=testing(model,test_loader,scaler)
# Out:
# ################################# 이상 감지 #################################
#
# time = 630
# Average_Back_Pressure가 정상 범위보다 -39.481116798688156 만큼 벗어났습니다.
# Barrel_Temperature_1가 정상 범위보다 -15.062974429598484 만큼 벗어났습니다.
# Barrel_Temperature_2가 정상 범위보다 -15.222763591445954 만큼 벗어났습니다.
# Barrel_Temperature_3가 정상 범위보다 -12.718309871456796 만큼 벗어났습니다.
# Barrel_Temperature_4가 정상 범위보다 -13.522529125213595 만큼 벗어났습니다.
# Barrel_Temperature_5가 정상 범위보다 -8.228906446414442 만큼 벗어났습니다.
# Barrel_Temperature_6가 정상 범위보다 -3.670965550169086 만큼 벗어났습니다.
# Clamp_Close_Time가 정상 범위보다 -0.5953678465201051 만큼 벗어났습니다.
# Clamp_Open_Position가 정상 범위보다 -320.27377400938803 만큼 벗어났습니다.
# Cushion_Position가 정상 범위보다 0.7474750894252793 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.7125625060130005 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 -1.8584843614490194 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -16.81900207302506 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 0.42755590124096443 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 -19.57461041477797 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 14.462426627832428 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 12.150719306148858 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.3481512131065756 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 -7.349579404682174 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.8336952520286331 만큼 벗어났습니다.
# Plasticizing_Position가 정상 범위보다 -4.560557952058538 만큼 벗어났습니다.
# Plasticizing_Time가 정상 범위보다 1.592074238775922 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 631
# Average_Back_Pressure가 정상 범위보다 -39.578641208152945 만큼 벗어났습니다.
# Barrel_Temperature_1가 정상 범위보다 -15.192088353409474 만큼 벗어났습니다.
# Barrel_Temperature_2가 정상 범위보다 -15.322311865165801 만큼 벗어났습니다.
# Barrel_Temperature_3가 정상 범위보다 -12.45510645593842 만큼 벗어났습니다.
# Barrel_Temperature_4가 정상 범위보다 -13.534340977668734 만큼 벗어났습니다.
# Barrel_Temperature_5가 정상 범위보다 -8.26018154656282 만큼 벗어났습니다.
# Barrel_Temperature_6가 정상 범위보다 -3.171295307315887 만큼 벗어났습니다.
# Clamp_Close_Time가 정상 범위보다 -0.5866048444748992 만큼 벗어났습니다.
# Clamp_Open_Position가 정상 범위보다 -321.63639689259526 만큼 벗어났습니다.
# Cushion_Position가 정상 범위보다 0.7492834087533993 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.673399556698314 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 -1.841609156849466 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -16.739858643886848 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 0.4319956427744387 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 -19.729836273909438 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 14.67577012617312 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 12.12801258626132 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.3473026948461211 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 -7.134818443619793 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.8321653202889365 만큼 벗어났습니다.
# Plasticizing_Position가 정상 범위보다 -4.57832349529388 만큼 벗어났습니다.
# Plasticizing_Time가 정상 범위보다 1.6152129072866046 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 636
# Average_Back_Pressure가 정상 범위보다 -39.47838675684505 만큼 벗어났습니다.
# Barrel_Temperature_1가 정상 범위보다 -15.286843520409263 만큼 벗어났습니다.
# Barrel_Temperature_2가 정상 범위보다 -15.022714147344203 만큼 벗어났습니다.
# Barrel_Temperature_3가 정상 범위보다 -12.349707756077805 만큼 벗어났습니다.
# Barrel_Temperature_4가 정상 범위보다 -12.532248094677897 만큼 벗어났습니다.
# Barrel_Temperature_5가 정상 범위보다 -8.155196576704157 만큼 벗어났습니다.
# Barrel_Temperature_6가 정상 범위보다 -3.171410201056716 만큼 벗어났습니다.
# Clamp_Close_Time가 정상 범위보다 -0.5863413908343853 만큼 벗어났습니다.
# Clamp_Open_Position가 정상 범위보다 -321.4013989115483 만큼 벗어났습니다.
# Cushion_Position가 정상 범위보다 0.7488841083541047 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.6833927658772154 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 -1.8525436039833392 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -16.837450198464197 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 0.4211228039148409 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 -19.836826592709517 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 14.473077552133873 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 12.232875777159279 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.3474657197864417 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 -7.536309950288626 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.4321897962588537 만큼 벗어났습니다.
# Plasticizing_Position가 정상 범위보다 -4.557027238698218 만큼 벗어났습니다.
# Plasticizing_Time가 정상 범위보다 1.5750179395654413 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 697
# Average_Back_Pressure가 정상 범위보다 -39.57966670610416 만큼 벗어났습니다.
# Barrel_Temperature_1가 정상 범위보다 -15.503993344469365 만큼 벗어났습니다.
# Barrel_Temperature_2가 정상 범위보다 -15.12123146094379 만큼 벗어났습니다.
# Barrel_Temperature_3가 정상 범위보다 -12.466515569092024 만큼 벗어났습니다.
# Barrel_Temperature_4가 정상 범위보다 -13.439066506922217 만큼 벗어났습니다.
# Barrel_Temperature_5가 정상 범위보다 -8.171030529935024 만큼 벗어났습니다.
# Barrel_Temperature_6가 정상 범위보다 -3.2709280415973865 만큼 벗어났습니다.
# Clamp_Close_Time가 정상 범위보다 -0.5872278838854266 만큼 벗어났습니다.
# Clamp_Open_Position가 정상 범위보다 -322.161893331363 만큼 벗어났습니다.
# Cushion_Position가 정상 범위보다 0.7502359335703659 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.6533297192813734 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 -1.8496895008125063 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -16.644448321367634 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 0.43402238730664067 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 -19.714703594453123 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 14.482006080459996 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 12.216484927097554 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.4469270534855241 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 -7.432184006280693 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -3.032273583321672 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.725283038571149 만큼 벗어났습니다.
# Plasticizing_Position가 정상 범위보다 -4.581191719205599 만큼 벗어났습니다.
# Plasticizing_Time가 정상 범위보다 1.5754098163533854 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 748
# Average_Back_Pressure가 정상 범위보다 -39.67950445864749 만큼 벗어났습니다.
# Barrel_Temperature_1가 정상 범위보다 -15.584290857845104 만큼 벗어났습니다.
# Barrel_Temperature_2가 정상 범위보다 -14.822341334074707 만큼 벗어났습니다.
# Barrel_Temperature_3가 정상 범위보다 -12.444891676538845 만큼 벗어났습니다.
# Barrel_Temperature_4가 정상 범위보다 -13.631169430911513 만큼 벗어났습니다.
# Barrel_Temperature_5가 정상 범위보다 -8.251612036537665 만큼 벗어났습니다.
# Barrel_Temperature_6가 정상 범위보다 -3.0711659575652277 만큼 벗어났습니다.
# Clamp_Close_Time가 정상 범위보다 -0.5962847736933554 만큼 벗어났습니다.
# Clamp_Open_Position가 정상 범위보다 -321.26833565691413 만큼 벗어났습니다.
# Cushion_Position가 정상 범위보다 0.7488197174461675 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.6831362686914417 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 -1.8535380312992698 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -16.533880705109283 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 0.4208279501177117 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 -20.142140054984573 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 14.472263328581903 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 12.333871693085712 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.34752722294342675 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 -7.7390992521901865 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -2.132646870355188 만큼 벗어났습니다.
# Plasticizing_Position가 정상 범위보다 -4.576213007540382 만큼 벗어났습니다.
# Plasticizing_Time가 정상 범위보다 1.6042651944853787 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 883
# Average_Back_Pressure가 정상 범위보다 -39.47846990532758 만큼 벗어났습니다.
# Barrel_Temperature_1가 정상 범위보다 -15.288651221830776 만큼 벗어났습니다.
# Barrel_Temperature_2가 정상 범위보다 -14.922573687508674 만큼 벗어났습니다.
# Barrel_Temperature_3가 정상 범위보다 -12.351572427353858 만큼 벗어났습니다.
# Barrel_Temperature_4가 정상 범위보다 -13.132974408566923 만큼 벗어났습니다.
# Barrel_Temperature_5가 정상 범위보다 -8.156915228004664 만큼 벗어났습니다.
# Barrel_Temperature_6가 정상 범위보다 -3.171371660751248 만큼 벗어났습니다.
# Clamp_Close_Time가 정상 범위보다 -0.5764317356816377 만큼 벗어났습니다.
# Clamp_Open_Position가 정상 범위보다 -321.48240892408467 만큼 벗어났습니다.
# Cushion_Position가 정상 범위보다 0.7490212389166118 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.6833963785136348 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 -1.8522201438448929 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -17.238285924074475 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 0.4214233025708154 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 -19.434413049450804 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 14.574005724356539 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 12.231204713065381 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.347409607878717 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 -7.235784986280123 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.4321801879918894 만큼 벗어났습니다.
# Plasticizing_Position가 정상 범위보다 -4.637476007290161 만큼 벗어났습니다.
# Plasticizing_Time가 정상 범위보다 1.4250869843763212 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 884
# Average_Back_Pressure가 정상 범위보다 -39.48005896521595 만큼 벗어났습니다.
# Barrel_Temperature_1가 정상 범위보다 -14.672465841327949 만큼 벗어났습니다.
# Barrel_Temperature_2가 정상 범위보다 -14.922727765515418 만큼 벗어났습니다.
# Barrel_Temperature_3가 정상 범위보다 -12.430767381708591 만큼 벗어났습니다.
# Barrel_Temperature_4가 정상 범위보다 -13.626400463283034 만큼 벗어났습니다.
# Barrel_Temperature_5가 정상 범위보다 -8.039350005194933 만큼 벗어났습니다.
# Barrel_Temperature_6가 정상 범위보다 -3.5711448637257206 만큼 벗어났습니다.
# Clamp_Close_Time가 정상 범위보다 -0.5757568259410846 만큼 벗어났습니다.
# Clamp_Open_Position가 정상 범위보다 -320.7222592277276 만큼 벗어났습니다.
# Cushion_Position가 정상 범위보다 0.7480385818416835 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.6828883104644774 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 -1.856130990994775 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -17.326291763160746 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 0.41897883848406536 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 -19.659610161879517 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 14.66668755555338 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 12.243588771547365 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.3478780296552486 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 -7.244338766831788 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.5331046850872099 만큼 벗어났습니다.
# Plasticizing_Position가 정상 범위보다 -4.62312922746586 만큼 벗어났습니다.
# Plasticizing_Time가 정상 범위보다 1.3932330588926334 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 887
# Average_Back_Pressure가 정상 범위보다 -39.579537364020226 만큼 벗어났습니다.
# Barrel_Temperature_1가 정상 범위보다 -15.484960534100338 만큼 벗어났습니다.
# Barrel_Temperature_2가 정상 범위보다 -15.322292195633025 만큼 벗어났습니다.
# Barrel_Temperature_3가 정상 범위보다 -12.54557646331844 만큼 벗어났습니다.
# Barrel_Temperature_4가 정상 범위보다 -12.331434294581385 만큼 벗어났습니다.
# Barrel_Temperature_5가 정상 범위보다 -8.35225829617147 만큼 벗어났습니다.
# Barrel_Temperature_6가 정상 범위보다 -3.2711487393843584 만큼 벗어났습니다.
# Clamp_Close_Time가 정상 범위보다 -0.5763184678181119 만큼 벗어났습니다.
# Clamp_Open_Position가 정상 범위보다 -321.29849895945426 만큼 벗어났습니다.
# Cushion_Position가 정상 범위보다 0.7488708655146183 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.6831375823774124 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 -1.853417210286541 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -17.43419411755167 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 0.42093988646757907 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 -20.04124232352702 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 14.572613419010395 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 12.233252001720757 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.4475066798363514 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 -7.138913721492941 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.8326438858935035 만큼 벗어났습니다.
# Plasticizing_Position가 정상 범위보다 -4.606378301955338 만큼 벗어났습니다.
# Plasticizing_Time가 정상 범위보다 1.524290869213928 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 935
# Average_Back_Pressure가 정상 범위보다 -39.47894108006192 만큼 벗어났습니다.
# Barrel_Temperature_1가 정상 범위보다 -15.209222434151854 만큼 벗어났습니다.
# Barrel_Temperature_2가 정상 범위보다 -14.721281835809322 만큼 벗어났습니다.
# Barrel_Temperature_3가 정상 범위보다 -12.57361340885521 만큼 벗어났습니다.
# Barrel_Temperature_4가 정상 범위보다 -13.941204428672762 만큼 벗어났습니다.
# Barrel_Temperature_5가 정상 범위보다 -7.976915816334554 만큼 벗어났습니다.
# Barrel_Temperature_6가 정상 범위보다 -3.271056751674138 만큼 벗어났습니다.
# Clamp_Close_Time가 정상 범위보다 -0.577433481430262 만큼 벗어났습니다.
# Clamp_Open_Position가 정상 범위보다 -322.41064577836823 만큼 벗어났습니다.
# Cushion_Position가 정상 범위보다 0.7505314024310792 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.6935386910502075 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 -1.8483342233602582 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -16.948735275704472 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 0.4247904008203136 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 -19.606235219567896 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 14.584297780897032 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 12.212716411073416 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.3467782952725429 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 -7.429066054009979 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -3.031897752263877 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.7257486699821243 만큼 벗어났습니다.
# Plasticizing_Position가 정상 범위보다 -4.632627235960207 만큼 벗어났습니다.
# Plasticizing_Time가 정상 범위보다 1.4861245537942978 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 955
# Average_Back_Pressure가 정상 범위보다 -39.5786134919921 만큼 벗어났습니다.
# Barrel_Temperature_1가 정상 범위보다 -15.297816376875915 만큼 벗어났습니다.
# Barrel_Temperature_2가 정상 범위보다 -14.422027822583885 만큼 벗어났습니다.
# Barrel_Temperature_3가 정상 범위보다 -12.261503371013333 만큼 벗어났습니다.
# Barrel_Temperature_4가 정상 범위보다 -12.536635711789103 만큼 벗어났습니다.
# Barrel_Temperature_5가 정상 범위보다 -8.065895598598104 만큼 벗어났습니다.
# Barrel_Temperature_6가 정상 범위보다 -3.2712512711404145 만큼 벗어났습니다.
# Clamp_Close_Time가 정상 범위보다 -0.5768740890318327 만큼 벗어났습니다.
# Clamp_Open_Position가 정상 범위보다 -321.89697335419623 만큼 벗어났습니다.
# Cushion_Position가 정상 범위보다 0.7496868355447077 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.6934746488591372 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 -1.8604594319557464 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -16.94306805442769 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 0.4129160198775139 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 -19.721755732398048 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 14.378564987524442 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 12.323041128522163 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.347129370205721 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 -7.932686859022397 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -2.232030072087383 만큼 벗어났습니다.
# Plasticizing_Position가 정상 범위보다 -4.609778622625264 만큼 벗어났습니다.
# Plasticizing_Time가 정상 범위보다 1.525584476568497 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 979
# Average_Back_Pressure가 정상 범위보다 30.672907024467726 만큼 벗어났습니다.
# Barrel_Temperature_6가 정상 범위보다 -0.8714355741103645 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.44832274249697 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 0.36532315308241436 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 0.41231215509737495 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 37.083633103267395 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -6.778649550465154 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 0.38760271222145093 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 2.2234233808949284 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 1701
# Cushion_Position가 정상 범위보다 0.2099287962496419 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 3.816126775020173 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -2.997422415586243 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 3.8630043085369934 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 5.735798235045195 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -17.583527382078493 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 10.123316384741884 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.8407022654866978 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.865409769151995 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 1702
# Average_Back_Pressure가 정상 범위보다 26.771908198673124 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.941135202793049 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 1.2819252412283433 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -3.7603754282636004 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 1.3157287412041399 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 33.87275148804917 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 3.3197047415050065 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -10.775976731081293 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 0.38783488462740934 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 6.122601853603101 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.6402492416213477 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.740552315624143 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 1703
# Cycle_Time가 정상 범위보다 2.8993911479147982 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 1.9108881285355324 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -3.041971902489877 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 1.9585869151347168 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 5.56029108753421 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 4.00643300971916 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -10.952883790297612 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.21245996018024016 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 7.623583640418474 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.740857497391488 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.773631028551847 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 1707
# Cushion_Position가 정상 범위보다 0.2099287962496419 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 3.816126775020173 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -2.997422415586243 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 3.8630043085369934 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 5.735798235045195 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -17.583527382078493 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 10.123316384741884 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.8407022654866978 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.865409769151995 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 1708
# Average_Back_Pressure가 정상 범위보다 26.771908198673124 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.941135202793049 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 1.2819252412283433 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -3.7603754282636004 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 1.3157287412041399 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 33.87275148804917 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 3.3197047415050065 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -10.775976731081293 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 0.38783488462740934 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 6.122601853603101 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.6402492416213477 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.740552315624143 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 1709
# Cycle_Time가 정상 범위보다 2.8993911479147982 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 1.9108881285355324 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -3.041971902489877 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 1.9585869151347168 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 5.56029108753421 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 4.00643300971916 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -10.952883790297612 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.21245996018024016 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 7.623583640418474 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.740857497391488 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.773631028551847 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 1726
# Cushion_Position가 정상 범위보다 0.2099287962496419 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 3.816126775020173 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -2.997422415586243 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 3.8630043085369934 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 5.735798235045195 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -17.583527382078493 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 10.123316384741884 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.8407022654866978 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.865409769151995 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 1727
# Average_Back_Pressure가 정상 범위보다 26.771908198673124 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.941135202793049 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 1.2819252412283433 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -3.7603754282636004 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 1.3157287412041399 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 33.87275148804917 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 3.3197047415050065 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -10.775976731081293 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 0.38783488462740934 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 6.122601853603101 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.6402492416213477 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.740552315624143 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 1728
# Cycle_Time가 정상 범위보다 2.8993911479147982 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 1.9108881285355324 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -3.041971902489877 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 1.9585869151347168 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 5.56029108753421 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 4.00643300971916 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -10.952883790297612 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.21245996018024016 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 7.623583640418474 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.740857497391488 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.773631028551847 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 1731
# Cushion_Position가 정상 범위보다 0.2099287962496419 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 3.816126775020173 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -2.997422415586243 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 3.8630043085369934 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 5.735798235045195 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -17.583527382078493 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 10.123316384741884 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.8407022654866978 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.865409769151995 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 1732
# Average_Back_Pressure가 정상 범위보다 26.771908198673124 만큼 벗어났습니다.
# Cycle_Time가 정상 범위보다 2.941135202793049 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 1.2819252412283433 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -3.7603754282636004 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 1.3157287412041399 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 33.87275148804917 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 3.3197047415050065 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -10.775976731081293 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 0.38783488462740934 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 6.122601853603101 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.6402492416213477 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.740552315624143 만큼 벗어났습니다.
# ################################# 이상 감지 #################################
#
# time = 1733
# Cycle_Time가 정상 범위보다 2.8993911479147982 만큼 벗어났습니다.
# Filling_Time가 정상 범위보다 1.9108881285355324 만큼 벗어났습니다.
# Hopper_Temperature가 정상 범위보다 -3.041971902489877 만큼 벗어났습니다.
# Injection_Time가 정상 범위보다 1.9585869151347168 만큼 벗어났습니다.
# Max_Back_Pressure가 정상 범위보다 5.56029108753421 만큼 벗어났습니다.
# Max_Injection_Pressure가 정상 범위보다 4.00643300971916 만큼 벗어났습니다.
# Max_Injection_Speed가 정상 범위보다 -10.952883790297612 만큼 벗어났습니다.
# Max_Screw_RPM가 정상 범위보다 -0.21245996018024016 만큼 벗어났습니다.
# Max_Switch_Over_Pressure가 정상 범위보다 7.623583640418474 만큼 벗어났습니다.
# Mold_Temperature_3가 정상 범위보다 -1.740857497391488 만큼 벗어났습니다.
# Mold_Temperature_4가 정상 범위보다 -1.773631028551847 만큼 벗어났습니다.
